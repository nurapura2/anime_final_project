# %% [markdown]
# # Importing requests libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Basic Data Inspection

# %%
df_raw = pd.read_csv('..\\..\\data\\raw\\anime_catalog.csv')
df = df_raw.copy()
df.sample(5)
# Out:
#                                           title_ru  \
# 5415                                  Суперкнига 2
# 6468   Трусливый велосипедист: Специальная поездка
# 1613                                    Паттен Рай
# 1678              Галактический экспресс 999 — ONA
# 10080                               Дзэгапэйн: STA
#
#                                                alt_names  anime_id status  \
# 5415   Anime oyako gekijô | Personal Computer Travel ...      7151  вышел
# 6468   Yowamushi Pedal OVA | Yowamushi Pedal: Special...      6044  вышел
# 1613   Batain Lai!! - Minami no Shima no Mizu Monogat...      7984  вышел
# 1678   Galaxy Express 999 (ONA) | Ginga Tetsudou 999 ...     12006  вышел
# 10080         Zegapain: STA | Дзегапейн: STA | ゼーガペインSTA     12168  вышел
#
#                        type        year age_rating  \
# 5415                 Сериал  Весна 1983         PG
# 6468                    OVA        2013      PG-13
# 1613   Полнометражный фильм        2008          G
# 1678                    ONA  Осень 2002          G
# 10080  Полнометражный фильм   Лето 2024      PG-13
#
#                                                   genres             source  \
# 5415   Приключения | Фантастика | Фэнтези | Исторический              Книга
# 6468                     Сёнэн | Драма | Комедия | Спорт              Манга
# 1613                       Исторический | Повседневность  оригинальная идея
# 1678           Драма | Приключения | Фантастика | Космос         Неизвестно
# 10080              Меха | Романтика | Фантастика | Экшен  Оригинальная идея
#
#                      studio  ... shikimori_url worldart_rating  worldart_url  \
# 5415   Tatsunoko Production  ...           NaN             NaN           NaN
# 6468      TMS Entertainment  ...           NaN             NaN           NaN
# 1613       Mushi Production  ...           NaN             NaN           NaN
# 1678         Toei Animation  ...           NaN             NaN           NaN
# 10080               Sunrise  ...           NaN             NaN           NaN
#
#        kinopoisk_rating                kinopoisk_url  mal_rating  mal_url  \
# 5415                6.8   //kinopoisk.ru/film/427012         NaN      NaN
# 6468                NaN  //kinopoisk.ru/film/4536410         NaN      NaN
# 1613                NaN  //kinopoisk.ru/film/4749120         NaN      NaN
# 1678                NaN                          NaN         NaN      NaN
# 10080               NaN                          NaN         NaN      NaN
#
#        comments_count  reviews_count  \
# 5415              NaN            NaN
# 6468              NaN            NaN
# 1613              NaN            NaN
# 1678              NaN            NaN
# 10080             NaN            NaN
#
#                                                      url
# 5415   https://old.yummyani.me/catalog/item/superkniga-2
# 6468   https://old.yummyani.me/catalog/item/truslivyy...
# 1613     https://old.yummyani.me/catalog/item/patten-ray
# 1678   https://old.yummyani.me/catalog/item/galaktich...
# 10080  https://old.yummyani.me/catalog/item/dzegapeyn...
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10142 entries, 0 to 10141
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_ru          10142 non-null  str
#  1   alt_names         10140 non-null  str
#  2   anime_id          10142 non-null  int64
#  3   status            10142 non-null  str
#  4   type              10142 non-null  str
#  5   year              9897 non-null   str
#  6   age_rating        10142 non-null  str
#  7   genres            10109 non-null  str
#  8   source            10142 non-null  str
#  9   studio            9698 non-null   str
#  10  director          8502 non-null   str
#  11  dubbing           8360 non-null   str
#  12  site_rating       10142 non-null  float64
#  13  site_votes        10142 non-null  int64
#  14  site_views        10142 non-null  str
#  15  shikimori_rating  0 non-null      float64
#  16  shikimori_url     0 non-null      float64
#  17  worldart_rating   0 non-null      float64
#  18  worldart_url      0 non-null      float64
#  19  kinopoisk_rating  4209 non-null   float64
#  20  kinopoisk_url     6959 non-null   str
#  21  mal_rating        0 non-null      float64
#  22  mal_url           0 non-null      float64
#  23  comments_count    0 non-null      float64
#  24  reviews_count     0 non-null      float64
#  25  url               10142 non-null  str
# dtypes: float64(10), int64(2), str(14)
# memory usage: 2.0 MB

# %%
df.describe()
# Out:
#            anime_id   site_rating    site_votes  shikimori_rating  \
# count  10142.000000  10142.000000  10142.000000               0.0
# mean    9006.145139      6.414001    261.780319               NaN
# std     5790.678239      1.830632    686.914423               NaN
# min        1.000000      0.000000      0.000000               NaN
# 25%     5749.250000      5.840000     14.000000               NaN
# 50%     8362.500000      6.760000     37.000000               NaN
# 75%    11157.750000      7.520000    165.000000               NaN
# max    28053.000000      9.540000   9435.000000               NaN
#
#        shikimori_url  worldart_rating  worldart_url  kinopoisk_rating  \
# count            0.0              0.0           0.0       4209.000000
# mean             NaN              NaN           NaN          6.982965
# std              NaN              NaN           NaN          0.798113
# min              NaN              NaN           NaN          3.400000
# 25%              NaN              NaN           NaN          6.400000
# 50%              NaN              NaN           NaN          6.900000
# 75%              NaN              NaN           NaN          7.600000
# max              NaN              NaN           NaN          9.100000
#
#        mal_rating  mal_url  comments_count  reviews_count
# count         0.0      0.0             0.0            0.0
# mean          NaN      NaN             NaN            NaN
# std           NaN      NaN             NaN            NaN
# min           NaN      NaN             NaN            NaN
# 25%           NaN      NaN             NaN            NaN
# 50%           NaN      NaN             NaN            NaN
# 75%           NaN      NaN             NaN            NaN
# max           NaN      NaN             NaN            NaN

# %%
print('data types: ')
df.dtypes
# Out:
# data types:
# title_ru                str
# alt_names               str
# anime_id              int64
# status                  str
# type                    str
# year                    str
# age_rating              str
# genres                  str
# source                  str
# studio                  str
# director                str
# dubbing                 str
# site_rating         float64
# site_votes            int64
# site_views              str
# shikimori_rating    float64
# shikimori_url       float64
# worldart_rating     float64
# worldart_url        float64
# kinopoisk_rating    float64
# kinopoisk_url           str
# mal_rating          float64
# mal_url             float64
# comments_count      float64
# reviews_count       float64
# url                     str
# dtype: object

# %%
print('num of rows and columns: ')
df.shape
# Out:
# num of rows and columns:
# (10142, 26)

# %%
print('columns names: ')
df.columns
# Out:
# columns names:
# Index(['title_ru', 'alt_names', 'anime_id', 'status', 'type', 'year',
#        'age_rating', 'genres', 'source', 'studio', 'director', 'dubbing',
#        'site_rating', 'site_votes', 'site_views', 'shikimori_rating',
#        'shikimori_url', 'worldart_rating', 'worldart_url', 'kinopoisk_rating',
#        'kinopoisk_url', 'mal_rating', 'mal_url', 'comments_count',
#        'reviews_count', 'url'],
#       dtype='str')

# %% [markdown]
# # 2. Missing Values

# %%
df.isnull().sum()
# Out:
# title_ru                0
# alt_names               2
# anime_id                0
# status                  0
# type                    0
# year                  245
# age_rating              0
# genres                 33
# source                  0
# studio                444
# director             1640
# dubbing              1782
# site_rating             0
# site_votes              0
# site_views              0
# shikimori_rating    10142
# shikimori_url       10142
# worldart_rating     10142
# worldart_url        10142
# kinopoisk_rating     5933
# kinopoisk_url        3183
# mal_rating          10142
# mal_url             10142
# comments_count      10142
# reviews_count       10142
# url                     0
# dtype: int64

# %%
#detecting missing values
missing = df.isnull().sum()
missing_pct = missing / df.shape[0] * 100
missing_above_20 = missing_pct[missing_pct > 20]

print('Columns with missing values > 20%:')
print('------------------------------------------------------------------------------------')
for col, pct in missing_above_20.items():
    print(f'{col}: {missing[col]} missing ({pct:.2f}%)')
print('------------------------------------------------------------------------------------')
print(f'Total columns affected: {len(missing_above_20)}')
# Out:
# Columns with missing values > 20%:
# ------------------------------------------------------------------------------------
# shikimori_rating: 10142 missing (100.00%)
# shikimori_url: 10142 missing (100.00%)
# worldart_rating: 10142 missing (100.00%)
# worldart_url: 10142 missing (100.00%)
# kinopoisk_rating: 5933 missing (58.50%)
# kinopoisk_url: 3183 missing (31.38%)
# mal_rating: 10142 missing (100.00%)
# mal_url: 10142 missing (100.00%)
# comments_count: 10142 missing (100.00%)
# reviews_count: 10142 missing (100.00%)
# ------------------------------------------------------------------------------------
# Total columns affected: 10

# %%
#dropping empty columns
missing_100 = missing_pct[missing_pct == 100]

for col, pct in missing_100.items():
    df = df.drop(columns=col)
    print(f'{col} has been dropped because it has 100% missing values')

df.shape
# Out:
# shikimori_rating has been dropped because it has 100% missing values
# shikimori_url has been dropped because it has 100% missing values
# worldart_rating has been dropped because it has 100% missing values
# worldart_url has been dropped because it has 100% missing values
# mal_rating has been dropped because it has 100% missing values
# mal_url has been dropped because it has 100% missing values
# comments_count has been dropped because it has 100% missing values
# reviews_count has been dropped because it has 100% missing values
# (10142, 18)

# %%
#column has only 2 miss, so filling it with empty string
df['alt_names'] = df['alt_names'].fillna('')

#filling missing values in 'year' column with median value
df['year'] = df['year'].str.extract('(\d{4})').astype(float)  # Extracting year as a 4-digit number and converting to float
df['year'] = df['year'].fillna(df['year'].median())
df['year'] = df['year'].astype(int)

#important column for our analysis, so filling missing values with 'Unknown'
df['genres'] = df['genres'].fillna('Unknown')



#filling missing values with median value
df['director'] = df['director'].fillna('Unknown')
df['dubbing'] = df['dubbing'].fillna('Unknown')
df['studio'] = df['studio'].fillna('Unknown')

#dropping columns that are not useful for our analysis and have many missing values
df = df.drop(columns=['kinopoisk_rating', 'kinopoisk_url'])

# %%
df.sample(25)
# Out:
#                                                title_ru  \
# 1472                          Белая Змея: Происхождение
# 7110                           Оммёдзи: История Хэйан 3
# 8344       Human Lost: Исповедь неполноценного человека
# 6670                            Счастливая звезда — OVA
# 5375                                          Пёс войны
# 4547           Карточные бои Авангарда: Неоновый Мессия
# 9008                    Убийца гоблинов: Корона гоблина
# 6374                    Любовный дневник Отомэ Надэсико
# 4875                                             Gakken
# 6678                                     Toei Animation
# 988                                ASK Animation Studio
# 8042                                             Gainax
# 9788                                        Studio Deen
# 5519                                   Polygon Pictures
# 205                                               M.S.C
#
#                     director  \
# 1472  Хуан Цзякан | Чжао Цзи
# 7110                 Unknown
# 8344        Кидзаки Фуминори
# 6670        Такэмото Ясухиро
# 5375           Эбата Хироюки
# 4547             Итагаки Син
# 9008         Одзаки Такахару
# 6374          Сампэй Хидзири
# 187                  Unknown
# 3697          Морисита Кодзо
# 4061           Окао Такахиро
# 4263             Наоя Такаси
# 6326          Окамура Тэнсай
# 3919           Касаи Кэнъити
# 9122                 Unknown
# 5343         Ватанабэ Такаси
# 8321           Исихара Тацуя
# 3743                 Unknown
# 4875                 Unknown
# 6678        Икухара Кунихико
# 988                  Unknown
# 8042        Катаяма Кадзуёси
# 9788               Кон Тиаки
# 5519          Сэсита Хироюки
# 205             Тада Сюнсукэ
#
#                                                 dubbing  site_rating  \
# 1472  Get Smart Group | Persona99 | AniPLague | Gran...         6.37
# 7110                                Panzu.info | ХЗ Лол         6.12
# 8344                                         ReAnimedia         6.38
# 6670      AniDUB | Люб. Многоголосый | Люб. Одноголосый         8.27
# 5375                                           Гаврилов         5.58
# 4547  Evolution Studio | Evolution Studio & CactusTe...         5.73
# 9008  OBELISK Project | Difar | Hans | Purple king |...         7.83
# 6374                                             AniDUB         5.87
# 187                                             Unknown         0.00
# 3697                                      SHIZA Project         6.86
# 4061                                           ANIvoice         6.09
# 4263  Dream Cast | Jerwis | Inferno_Phantom | Belka ...         6.38
# 6326  VoiceLand | RestlessBun | Zhaparr | Суми | Ким...         6.81
# 3919                               AniDUB | CACTUS team         7.45
# 9122                                            Unknown         0.00
# 5343                                 AniDUB | Persona99         5.80
# 8321  SHIZA Project | Акварелька | Abe | GreyMoon | ...         7.81
# 3743                                            Unknown         5.50
# 4875                                          Persona99         4.30
# 6678                                     СВ-Дубль | 2x2         8.09
# 988   LightFamily | Шмель | Salgerd | Аркеро | Ditar...         6.45
# 8042                                           Vinestra         7.19
# 9788                                Panzu.info | ХЗ Лол         6.49
# 5519  AniStar | Shoker | AlexFilm | AniDUB | AniFilm...         7.51
# 205                                       Arasi Project         6.72
#
#       site_votes          site_views  \
# 1472          72   27 311 просмотров
# 7110          16    4 515 просмотров
# 8344         112   38 014 просмотров
# 6670         156   27 876 просмотров
# 5375          12    4 036 просмотров
# 4547          11     5 583 просмотра
# 9008        1657   76 978 просмотров
# 6374          23    7 846 просмотров
# 187            0   85 706 просмотров
# 3697          21   11 196 просмотров
# 4061          11    3 826 просмотров
# 4263         638   204 942 просмотра
# 6326         151   45 118 просмотров
# 3919         279   59 466 просмотров
# 9122           0     5 104 просмотра
# 5343          10     4 132 просмотра
# 8321          94     17 051 просмотр
# 3743           2     4 332 просмотра
# 4875          10    3 467 просмотров
# 6678          94    25 532 просмотра
# 988          250  152 376 просмотров
# 8042          75   27 779 просмотров
# 9788         179     25 481 просмотр
# 5519         212   45 750 просмотров
# 205           18    6 714 просмотров
#
#                                                     url
# 1472  https://old.yummyani.me/catalog/item/belaya-zmeya
# 7110  https://old.yummyani.me/catalog/item/ommedzi-i...
# 8344  https://old.yummyani.me/catalog/item/human-los...
# 6670  https://old.yummyani.me/catalog/item/schastliv...
# 5375     https://old.yummyani.me/catalog/item/pes-voyny
# 4547  https://old.yummyani.me/catalog/item/kartochny...
# 9008  https://old.yummyani.me/catalog/item/ubiyca-go...
# 6374  https://old.yummyani.me/catalog/item/lyubovnyy...
# 187   https://old.yummyani.me/catalog/item/vsevedush...
# 3697  https://old.yummyani.me/catalog/item/budda-vel...
# 4061  https://old.yummyani.me/catalog/item/zabyt-pro...
# 4263  https://old.yummyani.me/catalog/item/skazanie-...
# 6326  https://old.yummyani.me/catalog/item/moya-gero...
# 3919  https://old.yummyani.me/catalog/item/lyubovnay...
# 9122  https://old.yummyani.me/catalog/item/potrevozh...
# 5343   https://old.yummyani.me/catalog/item/chernyy-lev
# 8321  https://old.yummyani.me/catalog/item/zvuchi-eu...
# 3743  https://old.yummyani.me/catalog/item/choegangg...
# 4875  https://old.yummyani.me/catalog/item/deti-v-pl...
# 6678  https://old.yummyani.me/catalog/item/sejlor-mu...
# 988   https://old.yummyani.me/catalog/item/posledniy...
# 8042  https://old.yummyani.me/catalog/item/yablochno...
# 9788  https://old.yummyani.me/catalog/item/kogda-pla...
# 5519        https://old.yummyani.me/catalog/item/blam-1
# 205   https://old.yummyani.me/catalog/item/princ-ten...

# %% [markdown]
# # 3. Data Types & Format Issues

# %%
print(df.dtypes)
# Out:
# title_ru           str
# alt_names          str
# anime_id         int64
# status             str
# type               str
# year             int64
# age_rating         str
# genres             str
# source             str
# studio             str
# director           str
# dubbing            str
# site_rating    float64
# site_votes       int64
# site_views         str
# url                str
# dtype: object

# %%
#converting columns to numeric
df['site_views'] = df['site_views'].str.extract('(\d+)').astype(int)
df['site_views']
# Out:
# 0         6
# 1         6
# 2         6
# 3         4
# 4        10
#          ..
# 10137    36
# 10138    28
# 10139     7
# 10140    10
# 10141     9
# Name: site_views, Length: 10142, dtype: int64

# %%
#splitting columns with multiple values into lists
df['genres'] = df['genres'].str.split('|')
df['alt_names'] = df['alt_names'].str.split('|')
df['studio'] = df['studio'].str.split('|')
df['director'] = df['director'].str.split('|')
df['dubbing'] = df['dubbing'].str.split('|')

# %%
df
# Out:
#                                                 title_ru  \
# 0                       Моя история продолжается сегодня
# 1      Детектив Конан: Цель — Когоро! Секретное рассл...
# 2        Сердце дракона: Хроника исследования мира духов
# 3                                        Госпожа Кэйфуку
# 4                   Ветер из Лояна: Таинственный мальчик
# ...                                                  ...
# 10137                    Проект Кей: Возвращение королей
# 10138                                      Великий блюз!
# 10139                      Мэйз: Пространство мегавзрыва
# 10140                                           Нарутару
# 10141                             Человеческие отношения
#
#                                                alt_names  anime_id status  \
# 0      [Kyou, Watashi no Monogatari ga Hashirimasu. ,...     10800  вышел
# 10137  [AniDUB ,  AniLibria ,  Onibaku ,  SHIZA Project]         7.79
# 10138  [AniLibria ,  Hoopoe ,  Renie ,  Frederica Izz...         5.23
# 10139       [Animegroup ,  Get Smart Group ,  Persona99]         5.73
# 10140                                           [AniDUB]         6.13
# 10141                                          [Unknown]         5.95
#
#        site_votes  site_views  \
# 0              19           6
# 1              23           6
# 2               5           6
# 3              18           4
# 4              19          10
# ...           ...         ...
# 10137         323          36
# 10138          30          28
# 10139          15           7
# 10140          23          10
# 10141          22           9
#
#                                                      url
# 0      https://old.yummyani.me/catalog/item/moya-isto...
# 1      https://old.yummyani.me/catalog/item/detektiv-...
# 2      https://old.yummyani.me/catalog/item/dragon-he...
# 3      https://old.yummyani.me/catalog/item/gospozha-...
# 4      https://old.yummyani.me/catalog/item/veter-iz-...
# ...                                                  ...
# 10137  https://old.yummyani.me/catalog/item/proekt-ke...
# 10138  https://old.yummyani.me/catalog/item/velikij-b...
# 10139  https://old.yummyani.me/catalog/item/meyz-pros...
# 10140      https://old.yummyani.me/catalog/item/narutaru
# 10141  https://old.yummyani.me/catalog/item/chelovech...
#
# [10142 rows x 16 columns]

# %% [markdown]
# # 4. Duplicate Data

# %%
#checking and resolving duplicate anime_id
dup_ids = df[df['anime_id'].duplicated(keep=False)]
print(f"Rows with duplicate anime_id: {len(dup_ids)}")

#keeping only the first occurrence
df = df.drop_duplicates(subset='anime_id', keep='first')
print(f"Shape after deduplication: {df.shape}")
# Out:
# Rows with duplicate anime_id: 0
# Shape after deduplication: (10142, 16)

# %% [markdown]
# # 5. Invalid or Suspicious Values

# %%
#manually checking for issues in the data
issues = {}

issues['year_out_of_range'] = df[(df['year'] < 1900) | (df['year'] > 2030)]
issues['rating_out_of_range'] = df[(df['site_rating'] < 0) | (df['site_rating'] > 10)]
issues['votes_negative'] = df[df['site_votes'] < 0]
issues['views_negative'] = df[df['site_views'] < 0]
issues['duplicate_anime_id'] = df[df['anime_id'].duplicated(keep=False)]
issues['empty_title'] = df[df['title_ru'].isna()]
issues['empty_type'] = df[df['type'].isna()]
issues['empty_status'] = df[df['status'].isna()]
issues['empty_genres'] = df[df['genres'].isna()]

# %%
issues
# Out:
# {'year_out_of_range': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'rating_out_of_range': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'votes_negative': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'views_negative': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'duplicate_anime_id': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'empty_title': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'empty_type': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'empty_status': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: [],
#  'empty_genres': Empty DataFrame
#  Columns: [title_ru, alt_names, anime_id, status, type, year, age_rating, genres, source, studio, director, dubbing, site_rating, site_votes, site_views, url]
#  Index: []}

# %%
num_cols = ['year', 'site_rating', 'site_votes', 'site_views']


#z-score method
z_scores = (df[num_cols] - df[num_cols].mean()) / df[num_cols].std()
z_outliers = np.abs(z_scores) > 3

#iqr method
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

iqr_outliers = (df[num_cols] < (Q1 - 1.5 * IQR)) | (df[num_cols] > (Q3 + 1.5 * IQR))

#merging outliers from both methods
outliers = z_outliers | iqr_outliers

#rows with issues
df_outliers = df[outliers.any(axis=1)]

#marking
df['suspicious'] = outliers.any(axis=1)

#checking
df_outliers[num_cols].sample(50)


df = df.drop(columns='suspicious')

# %% [markdown]
# We examined the outliers and suspicious values, but concluded that in this case they cannot be analyzed reliably due to the very high variance. We also believe these values are valid, as such data can realistically occur. Therefore, we decided not to remove these outliers

# %%
# final validation
print("Final shape")
print(df.shape)

print("Remaining missing values")
print(df.isnull().sum())

print("Data types")
print(df.dtypes)
# Out:
# Final shape
# (10142, 17)
# Remaining missing values
# title_ru       0
# alt_names      0
# anime_id       0
# status         0
# type           0
# year           0
# age_rating     0
# genres         0
# source         0
# studio         0
# director       0
# dubbing        0
# site_rating    0
# site_votes     0
# site_views     0
# url            0
# suspicious     0
# dtype: int64
# Data types
# title_ru           str
# alt_names       object
# anime_id         int64
# status             str
# type               str
# year             int64
# age_rating         str
# genres          object
# source             str
# studio          object
# director        object
# dubbing         object
# site_rating    float64
# site_votes       int64
# site_views       int64
# url                str
# suspicious        bool
# dtype: object

# %%
df
# Out:
#                                                 title_ru  \
# 0                       Моя история продолжается сегодня
# 1      Детектив Конан: Цель — Когоро! Секретное рассл...
# 2        Сердце дракона: Хроника исследования мира духов
# 3                                        Госпожа Кэйфуку
# 4                   Ветер из Лояна: Таинственный мальчик
# ...                                                  ...
# 10137                    Проект Кей: Возвращение королей
# 10138                                      Великий блюз!
# 10139                      Мэйз: Пространство мегавзрыва
# 10140                                           Нарутару
# 10141                             Человеческие отношения
#
#                                                alt_names  anime_id status  \
# 0      [Kyou, Watashi no Monogatari ga Hashirimasu. ,...     10800  вышел
# 1      [Detective Conan OVA 05: The Target is Kogoro!...      8258  вышел
# 2      [Dragon Heart: Adventures Beyond This World , ...     18742  вышел
# 3      [Keifuku-san ,  Keifukusan ,  Пані Кейфуку ,  ...      6905  вышел
# 4      [Feng qi luo yang zhi shen ji shao nian ,  Fen...      6198  вышел
# ...                                                  ...       ...    ...
# 10137  [K ,  K 2nd Season ,  K RETURN OF KINGS ,  K-P...      7262  вышел
# 10138  [Grablu! ,  Grand Blues! ,  Guraburu! ,  Грабл...      1561  вышел
# 10139  [Maze bakunetsu jikû ,  Maze: The Mega-Burst S...      6910  вышел
# 10140  [Narutaru: Mukuro naru hoshi tama taru ko ,  S...      9458  вышел
# 10141  [Homeroom Affairs ,  Human Relations ,  Tanin ...      7178  вышел
#
#                        type  year age_rating  \
# 0                       ONA  2023          G
# 1                       OVA  2005      PG-13
# 2      Полнометражный фильм  2025          G
# 3                       ONA  2017          G
# 4                       ONA  2021      PG-13
# ...                     ...   ...        ...
# 10137                Сериал  2015      PG-13
# 10138  Малометражный сериал  2020      PG-13
# 10139                Сериал  1997      PG-13
# 10140                Сериал  2003      R-17+
# 10141                   OVA  1994         R+
#
#                                                   genres             source  \
# 0                              [Повседневность ,  Спорт]  Оригинальная идея
# 1      [Сёнэн ,  Детектив ,  Комедия ,  Приключения ,...              Манга
# 2             [Фэнтези ,  Драконы ,  Сверхъестественное]  Оригинальная идея
# 3                                              [Фэнтези]  Оригинальная идея
# 4      [Детектив ,  Приключения ,  Фэнтези ,  Экшен ,...  Оригинальная идея
# ...                                                  ...                ...
# 10137             [Фэнтези ,  Экшен ,  Суперспособности]  Оригинальная идея
# 10138                           [Приключения ,  Фэнтези]              Манга
# 10139  [Сёнэн ,  Комедия ,  Меха ,  Пилотируемые робо...             Ранобэ
# 10140            [Сэйнэн ,  Драма ,  Триллер ,  Фэнтези]              Манга
# 10141   [Этти ,  Комедия ,  Романтика ,  Школьная жизнь]              Манга
#
#                                    studio  \
# 0                       [Studio Colorido]
# 1                     [TMS Entertainment]
# 2                    [HS Pictures Studio]
# 3                             [Yaoyorozu]
# 4                                [Chosen]
# ...                                   ...
# 10137                           [GoHands]
# 10138  [W-Toon Studio ,  DMM.futureworks]
# 10139                         [J.C.Staff]
# 10140                            [Planet]
# 10141                         [J.C.Staff]
#
#                                     director  \
# 0                            [Синго Ямасита]
# 1                              [Сато Масато]
# 2                            [Имакакэ Исаму]
# 3                                   [Тацуки]
# 4                                  [Unknown]
# ...                                      ...
# 10137  [Судзуки Синго ,  Канадзава Хиромити]
# 10138                        [Мории Кэнсиро]
# 10139                          [Судзуки Ику]
# 10140                         [Иино Тосиаки]
# 10141                         [Сэкита Осаму]
#
#                                                  dubbing  site_rating  \
# 0                                              [AniLane]         6.74
# 1                                            [Persona99]         6.65
# 2                                              [Unknown]         5.60
# 3                                 [Panzu.info ,  ХЗ Лол]         5.28
# 4                    [AniStar ,  Автоперевод ,  ПВА ШОУ]         6.42
# ...                                                  ...          ...
# 10137  [AniDUB ,  AniLibria ,  Onibaku ,  SHIZA Project]         7.79
# 10138  [AniLibria ,  Hoopoe ,  Renie ,  Frederica Izz...         5.23
# 10139       [Animegroup ,  Get Smart Group ,  Persona99]         5.73
# 10140                                           [AniDUB]         6.13
# 10141                                          [Unknown]         5.95
#
#        site_votes  site_views  \
# 0              19           6
# 1              23           6
# 2               5           6
# 3              18           4
# 4              19          10
# ...           ...         ...
# 10137         323          36
# 10138          30          28
# 10139          15           7
# 10140          23          10
# 10141          22           9
#
#                                                      url
# 0      https://old.yummyani.me/catalog/item/moya-isto...
# 1      https://old.yummyani.me/catalog/item/detektiv-...
# 2      https://old.yummyani.me/catalog/item/dragon-he...
# 3      https://old.yummyani.me/catalog/item/gospozha-...
# 4      https://old.yummyani.me/catalog/item/veter-iz-...
# ...                                                  ...
# 10137  https://old.yummyani.me/catalog/item/proekt-ke...
# 10138  https://old.yummyani.me/catalog/item/velikij-b...
# 10139  https://old.yummyani.me/catalog/item/meyz-pros...
# 10140      https://old.yummyani.me/catalog/item/narutaru
# 10141  https://old.yummyani.me/catalog/item/chelovech...
#
# [10142 rows x 16 columns]

# %%
#saving cleaned dataframe
df.to_csv('../../data/processed/anime_catalog_clean.csv', index=False)
print("Saved successfully!")
# Out:
# Saved successfully!
